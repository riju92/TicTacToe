# %%
import numpy as np
dataset = np.loadtxt('tictac_single.txt')

# %%
np.random.shuffle(dataset)

# %%
X = dataset[:, :9]
Y = dataset[:,9:]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (6551, 9)
# (6551, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix

# %%
def KNN(train_X, test_X, train_Y, test_Y):
    n_neighbors = 30
    print(test_X.shape)
    print(test_Y.shape)
    print(train_X.shape)
    print(train_Y.shape)
    
    
    clf = KNeighborsClassifier(n_neighbors, weights='uniform')
    clf.fit(train_X, train_Y)
    res = clf.predict(test_X)
    res_cm = res
    res = np.asarray(res)
    res = np.reshape(res, (-1, test_Y.shape[0]))
    accuracy = 0.0
    for i in range(res.shape[1]):
        if(res[0][i] == test_Y[i][0]):
            accuracy += 1
    print(accuracy)
    print("Accuracy = " + str(accuracy/res.shape[1]))
    print("#### CONFUSION MATRIX ##########")
    cm = confusion_matrix(test_Y, res_cm)
    cm = cm / cm.sum(axis=1)[:, np.newaxis]
    print(cm)
    return accuracy/res.shape[1], clf

# %%
#train_X = X[0:800]
#test_X = X[800:958]
#train_Y = Y[0:800]
#test_Y = Y[800:958]

#print(test_Y.shape)
#print(test_Y)
#k fold validation
#k_cross_fold = 1

#res = linearSVM(train_X, test_X, train_Y, test_Y)

# %%
from sklearn.model_selection import StratifiedKFold

accuracy_max = 0.0
accuracy_min = 100.0
accuracy_avg = 0.0

best_clf = 0

k_cross_fold = 10

skf = StratifiedKFold(n_splits=k_cross_fold)
for train_index, test_index in skf.split(X, Y):
    train_X, test_X = X[train_index], X[test_index]
    train_Y, test_Y = Y[train_index], Y[test_index]
    
    accuracy, clf = KNN(train_X, test_X, train_Y, test_Y)
    accuracy *= 100
    
    if(accuracy > accuracy_max):
        accuracy_max = accuracy
        best_clf = clf
    accuracy_min = min(accuracy_min, accuracy)
    accuracy_avg += accuracy
    
    print("#######################")
    
print("Max accuracy = " + str(accuracy_max))
print("Min accuracy = " + str(accuracy_min))
print("Avg accuracy = " + str(accuracy_avg/k_cross_fold))
# Out:
# (656, 9)
# (656, 1)
# (5895, 9)
# (5895, 1)
# 461.0
# Accuracy = 0.7027439024390244
# #### CONFUSION MATRIX ##########
# [[0.94871795 0.00641026 0.00641026 0.00641026 0.03205128 0.
#   0.         0.         0.        ]
#  [0.08333333 0.66666667 0.08333333 0.05952381 0.07142857 0.01190476
#   0.         0.         0.02380952]
#  [0.20408163 0.10204082 0.62244898 0.04081633 0.02040816 0.
#   0.01020408 0.         0.        ]
#  [0.07843137 0.05882353 0.         0.58823529 0.19607843 0.
#   0.05882353 0.         0.01960784]
#  [0.22857143 0.05714286 0.00952381 0.01904762 0.66666667 0.
#   0.01904762 0.         0.        ]
#  [0.14285714 0.11428571 0.         0.02857143 0.14285714 0.48571429
#   0.08571429 0.         0.        ]
#  [0.2        0.01818182 0.03636364 0.07272727 0.01818182 0.
#   0.65454545 0.         0.        ]
#  [0.23076923 0.11538462 0.         0.03846154 0.         0.
#   0.         0.61538462 0.        ]
#  [0.23913043 0.06521739 0.06521739 0.02173913 0.         0.
#   0.         0.02173913 0.58695652]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# 506.0
# Accuracy = 0.7725190839694657
# #### CONFUSION MATRIX ##########
# [[0.92948718 0.         0.01923077 0.01282051 0.02564103 0.
#   0.         0.         0.01282051]
#  [0.05952381 0.73809524 0.05952381 0.02380952 0.08333333 0.01190476
#   0.01190476 0.         0.01190476]
#  [0.10204082 0.04081633 0.75510204 0.         0.07142857 0.01020408
#   0.         0.01020408 0.01020408]
#  [0.15686275 0.05882353 0.05882353 0.58823529 0.03921569 0.
#   0.01960784 0.         0.07843137]
#  [0.15238095 0.01904762 0.00952381 0.         0.80952381 0.
#   0.00952381 0.         0.        ]
#  [0.05714286 0.17142857 0.05714286 0.         0.02857143 0.62857143
#   0.02857143 0.02857143 0.        ]
#  [0.09090909 0.03636364 0.03636364 0.         0.03636364 0.
#   0.78181818 0.         0.01818182]
#  [0.2        0.12       0.         0.2        0.08       0.
#   0.04       0.36       0.        ]
#  [0.15217391 0.04347826 0.         0.         0.02173913 0.
#   0.         0.         0.7826087 ]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# 502.0
# Accuracy = 0.766412213740458
# #### CONFUSION MATRIX ##########
# [[0.92993631 0.00636943 0.00636943 0.01910828 0.02547771 0.01273885
#   0.         0.         0.        ]
#  [0.03571429 0.73809524 0.05952381 0.01190476 0.14285714 0.01190476
#   0.         0.         0.        ]
#  [0.05154639 0.06185567 0.75257732 0.02061856 0.08247423 0.
#   0.02061856 0.         0.01030928]
#  [0.03921569 0.07843137 0.01960784 0.62745098 0.09803922 0.01960784
#   0.03921569 0.         0.07843137]
#  [0.13333333 0.01904762 0.00952381 0.00952381 0.80952381 0.
#   0.01904762 0.         0.        ]
#  [0.14285714 0.05714286 0.         0.         0.05714286 0.62857143
#   0.08571429 0.         0.02857143]
#  [0.18181818 0.05454545 0.01818182 0.01818182 0.03636364 0.01818182
#   0.67272727 0.         0.        ]
#  [0.12       0.04       0.04       0.08       0.04       0.
#   0.04       0.64       0.        ]
#  [0.17391304 0.08695652 0.04347826 0.04347826 0.02173913 0.
#   0.         0.         0.63043478]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# 537.0
# Accuracy = 0.8198473282442749
# #### CONFUSION MATRIX ##########
# [[0.94267516 0.         0.01273885 0.00636943 0.03821656 0.
#   0.         0.         0.        ]
#  [0.05952381 0.83333333 0.02380952 0.01190476 0.05952381 0.
#   0.01190476 0.         0.        ]
#  [0.06185567 0.03092784 0.81443299 0.02061856 0.03092784 0.01030928
#   0.01030928 0.         0.02061856]
#  [0.1372549  0.03921569 0.01960784 0.62745098 0.05882353 0.
#   0.05882353 0.03921569 0.01960784]
#  [0.06666667 0.00952381 0.01904762 0.00952381 0.8952381  0.
#   0.         0.         0.        ]
#  [0.17142857 0.08571429 0.11428571 0.02857143 0.05714286 0.48571429
#   0.         0.         0.05714286]
#  [0.07272727 0.         0.03636364 0.01818182 0.05454545 0.
#   0.76363636 0.         0.05454545]
#  [0.08       0.04       0.04       0.         0.04       0.04
#   0.         0.72       0.04      ]
#  [0.10869565 0.04347826 0.02173913 0.02173913 0.         0.
#   0.         0.         0.80434783]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# 520.0
# Accuracy = 0.7938931297709924
# #### CONFUSION MATRIX ##########
# [[0.9044586  0.02547771 0.00636943 0.01273885 0.02547771 0.00636943
#   0.         0.00636943 0.01273885]
#  [0.08235294 0.75294118 0.03529412 0.02352941 0.04705882 0.
#   0.03529412 0.         0.02352941]
#  [0.08247423 0.02061856 0.80412371 0.02061856 0.05154639 0.
#   0.01030928 0.01030928 0.        ]
#  [0.05882353 0.01960784 0.01960784 0.70588235 0.09803922 0.
#   0.05882353 0.         0.03921569]
#  [0.03809524 0.01904762 0.02857143 0.         0.91428571 0.
#   0.         0.         0.        ]
#  [0.11428571 0.14285714 0.05714286 0.         0.02857143 0.6
#   0.02857143 0.02857143 0.        ]
#  [0.09259259 0.03703704 0.03703704 0.03703704 0.05555556 0.
#   0.7037037  0.         0.03703704]
#  [0.28       0.         0.08       0.         0.         0.
#   0.08       0.52       0.04      ]
#  [0.13043478 0.04347826 0.         0.         0.10869565 0.
#   0.02173913 0.         0.69565217]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# 545.0
# Accuracy = 0.8320610687022901
# #### CONFUSION MATRIX ##########
# [[0.93630573 0.03184713 0.00636943 0.01273885 0.00636943 0.00636943
#   0.         0.         0.        ]
#  [0.02352941 0.85882353 0.05882353 0.         0.01176471 0.01176471
#   0.01176471 0.         0.02352941]
#  [0.05154639 0.07216495 0.80412371 0.         0.07216495 0.
#   0.         0.         0.        ]
#  [0.1372549  0.01960784 0.         0.68627451 0.11764706 0.01960784
#   0.         0.         0.01960784]
#  [0.03846154 0.00961538 0.00961538 0.         0.92307692 0.
#   0.01923077 0.         0.        ]
#  [0.05555556 0.02777778 0.08333333 0.         0.08333333 0.72222222
#   0.02777778 0.         0.        ]
#  [0.11111111 0.         0.09259259 0.03703704 0.05555556 0.
#   0.68518519 0.         0.01851852]
#  [0.16       0.12       0.04       0.         0.04       0.
#   0.         0.6        0.04      ]
#  [0.10869565 0.         0.02173913 0.         0.04347826 0.
#   0.         0.         0.82608696]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# 528.0
# Accuracy = 0.8061068702290076
# #### CONFUSION MATRIX ##########
# [[0.91025641 0.00641026 0.02564103 0.01923077 0.02564103 0.
#   0.01282051 0.         0.        ]
#  [0.04705882 0.74117647 0.05882353 0.02352941 0.07058824 0.01176471
#   0.01176471 0.         0.03529412]
#  [0.04123711 0.04123711 0.8556701  0.         0.04123711 0.
#   0.         0.01030928 0.01030928]
#  [0.05769231 0.01923077 0.05769231 0.69230769 0.09615385 0.03846154
#   0.01923077 0.         0.01923077]
#  [0.02884615 0.         0.01923077 0.01923077 0.91346154 0.00961538
#   0.00961538 0.         0.        ]
#  [0.11111111 0.05555556 0.         0.02777778 0.02777778 0.75
#   0.         0.         0.02777778]
#  [0.12962963 0.09259259 0.01851852 0.         0.05555556 0.
#   0.7037037  0.         0.        ]
#  [0.08       0.16       0.         0.04       0.08       0.04
#   0.         0.56       0.04      ]
#  [0.13043478 0.08695652 0.04347826 0.         0.06521739 0.02173913
#   0.         0.         0.65217391]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# 551.0
# Accuracy = 0.8412213740458016
# #### CONFUSION MATRIX ##########
# [[0.94230769 0.00641026 0.01923077 0.00641026 0.02564103 0.
#   0.         0.         0.        ]
#  [0.07058824 0.72941176 0.07058824 0.02352941 0.04705882 0.01176471
#   0.02352941 0.         0.02352941]
#  [0.03092784 0.01030928 0.91752577 0.02061856 0.02061856 0.
#   0.         0.         0.        ]
#  [0.07692308 0.09615385 0.07692308 0.67307692 0.03846154 0.
#   0.01923077 0.         0.01923077]
#  [0.02884615 0.05769231 0.         0.         0.90384615 0.
#   0.00961538 0.         0.        ]
#  [0.11111111 0.08333333 0.02777778 0.         0.         0.75
#   0.         0.02777778 0.        ]
#  [0.01851852 0.03703704 0.01851852 0.03703704 0.03703704 0.
#   0.85185185 0.         0.        ]
#  [0.07692308 0.07692308 0.         0.03846154 0.         0.03846154
#   0.         0.76923077 0.        ]
#  [0.24444444 0.         0.         0.02222222 0.02222222 0.02222222
#   0.         0.         0.68888889]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
# 533.0
# Accuracy = 0.8137404580152672
# #### CONFUSION MATRIX ##########
# [[0.91666667 0.01282051 0.00641026 0.00641026 0.03846154 0.01282051
#   0.00641026 0.         0.        ]
#  [0.01176471 0.8        0.02352941 0.         0.11764706 0.
#   0.02352941 0.         0.02352941]
#  [0.12371134 0.03092784 0.77319588 0.01030928 0.05154639 0.
#   0.01030928 0.         0.        ]
#  [0.07692308 0.         0.         0.61538462 0.21153846 0.
#   0.07692308 0.01923077 0.        ]
#  [0.00961538 0.02884615 0.         0.         0.94230769 0.01923077
#   0.         0.         0.        ]
#  [0.05714286 0.02857143 0.         0.02857143 0.08571429 0.71428571
#   0.05714286 0.02857143 0.        ]
#  [0.03703704 0.01851852 0.05555556 0.01851852 0.07407407 0.
#   0.7962963  0.         0.        ]
#  [0.15384615 0.         0.         0.03846154 0.07692308 0.
#   0.         0.69230769 0.03846154]
#  [0.15217391 0.         0.06521739 0.         0.08695652 0.
#   0.02173913 0.         0.67391304]]
# #######################
# (655, 9)
# (655, 1)
# (5896, 9)
# (5896, 1)
# 543.0
# Accuracy = 0.8290076335877863
# #### CONFUSION MATRIX ##########
# [[0.94230769 0.01282051 0.00641026 0.00641026 0.02564103 0.
#   0.00641026 0.         0.        ]
#  [0.01190476 0.75       0.05952381 0.03571429 0.08333333 0.01190476
#   0.01190476 0.01190476 0.02380952]
#  [0.02040816 0.01020408 0.90816327 0.02040816 0.04081633 0.
#   0.         0.         0.        ]
#  [0.1372549  0.09803922 0.01960784 0.70588235 0.         0.
#   0.         0.         0.03921569]
#  [0.03809524 0.00952381 0.         0.01904762 0.93333333 0.
#   0.         0.         0.        ]
#  [0.22857143 0.02857143 0.05714286 0.05714286 0.         0.57142857
#   0.05714286 0.         0.        ]
#  [0.18518519 0.03703704 0.01851852 0.01851852 0.         0.
#   0.74074074 0.         0.        ]
#  [0.19230769 0.11538462 0.03846154 0.         0.03846154 0.
#   0.         0.61538462 0.        ]
#  [0.23913043 0.02173913 0.         0.         0.         0.
#   0.         0.         0.73913043]]
# #######################
# Max accuracy = 84.12213740458016
# Min accuracy = 70.27439024390245
# Avg accuracy = 79.77553062744366
# <ipython-input-1-441419a3d114>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(train_X, train_Y)
